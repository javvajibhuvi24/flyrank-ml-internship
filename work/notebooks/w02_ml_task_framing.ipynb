# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/javvajibhuvi24/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
#My lane is to identify pages that are likely to be declining and therefore worth reviewing. This is a binary classification problem because each page can be classified as likely declining or not declining. The model would use observable signals such as impressions, position, CTR, content age, update recency, and word count.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
import os
import subprocess
import sys

REPO_URL = "https://github.com/javvajibhuvi24/flyrank-ml-internship.git"
REPO_DIR = "/content/flyrank-ml-internship"

if not os.path.exists(REPO_DIR):
    subprocess.run(
        ["git", "clone", "--depth", "1", REPO_URL, REPO_DIR],
        check=True
    )

os.chdir(REPO_DIR)

print("Working folder:", os.getcwd())
print("Files:", os.listdir()[:10])
# Out:
# Working folder: /content/flyrank-ml-internship
# Files: ['scripts', '.github', 'AGENTS.md', 'submission', 'outputs', '.gitignore', 'SETUP.md', 'skills', 'GUIDE.md', 'notebooks']

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
df["is_declining_label"] = (
    df["trend_direction"].str.lower() == "down"
).astype(int)

print("Declining rate:", round(df["is_declining_label"].mean(), 3))
# Out:
# Declining rate: 0.542

# %%
#The target is whether a page is declining. In the starter data, this is derived from trend_direction. For a future production version, I would make sure the prediction uses only information that would be available before the outcome occurs and avoid leakage from trend_direction or trend_pct.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
#I will use Precision@50 because the practical decision is to create a small review queue. I care about how many of the top 50 recommended pages are actually declining. A high precision means the team spends less time reviewing pages that do not need attention.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df[[
    "impressions_90d",
    "avg_position",
    "ctr",
    "content_age_days",
    "days_since_last_update",
    "word_count",
    "trend_direction"
]].head()
# Out:
#    impressions_90d  avg_position   ctr  content_age_days  \
# 0             3803          10.6  0.76               187
# 1            15320          20.3  0.05               445
# 2            12581          36.5  0.09               141
# 3            11751           6.2  0.49               463
# 4            19140          44.0  0.13               263
#
#    days_since_last_update  word_count trend_direction
# 0                      20      3221.0            down
# 1                      25      2481.0            down
# 2                      20      3515.0            down
# 3                      22         NaN          stable
# 4                      14      2803.0            down

# %%
#The unit of analysis is a page. Each row represents one anonymized page and contains observable search/content signals that can be used to assess whether the page may need review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
#A fixed rule such as “flag pages older than 180 days with more than 500 impressions” is easy to understand, but it depends on manually chosen thresholds and may miss combinations of signals. ML can learn interactions between several observable features and rank pages by their estimated likelihood of declining. The starter notebooks already showed that a learned model can sometimes outperform a simple hand rule, although this needs to be tested with proper holdout validation rather than assumed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✓] Every section above is filled — markdown thinking AND the code that backs it
# - [✓] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✓] No client names, URLs, or private queries anywhere
# - [✓] My claims use careful words: observed, measured, directional, decision-support
# - [✓] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
